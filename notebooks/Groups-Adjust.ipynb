# %% [markdown]
# # Load Data

# %%
import music21
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import mnet
# Out:
# music21: Certain music21 functions might need the optional package scipy;
#                   if you run into errors, install it by following the instructions at
#                   http://mit.edu/music21/doc/installing/installAdditional.html

# %% [markdown]
# Create path to access local files

# %%
'''
Creat local corpus with access pieces
'''

localCorpus = music21.corpus.corpora.LocalCorpus()
localCorpus.addPath('../library')
music21.corpus.cacheMetadata()
# Out:
# /opt/anaconda3/envs/music-network-env/lib/python3.7/site-packages/music21/corpus/corpora.py: WARNING: local metadata cache: starting processing of paths: 2
# /opt/anaconda3/envs/music-network-env/lib/python3.7/site-packages/music21/corpus/corpora.py: WARNING: cache: filename: /var/folders/j6/2q7hftds7vb8_lsfy50l8lzw0000gn/T/music21/local.p.gz
# bundles.py: WARNING: MetadataBundle Modification Time: 1595562629.2728076
# bundles.py: WARNING: Skipped 0 sources already in cache.
# bundles.py: WARNING: updated 1 of 2 files; total errors: 0 ... last file: /Users/kaitlinpet/Desktop/Projects/network-composition/library/telemannfantasie1.xml
# bundles.py: WARNING: updated 2 of 2 files; total errors: 0 ... last file: /Users/kaitlinpet/Desktop/Projects/network-composition/library/beethoven_fur_elise.xml
# /opt/anaconda3/envs/music-network-env/lib/python3.7/site-packages/music21/corpus/corpora.py: WARNING: cache: writing time: 1.809 md items: 2
#
# /opt/anaconda3/envs/music-network-env/lib/python3.7/site-packages/music21/corpus/corpora.py: WARNING: cache: filename: /var/folders/j6/2q7hftds7vb8_lsfy50l8lzw0000gn/T/music21/local.p.gz
# caching.py: WARNING: cache: final writing time: 1.81 seconds

# %% [markdown]
# Save Telemann Fantasie No. 1 as a stream object

# %%
s = music21.corpus.parse('telemannfantasie1.xml')

# %% [markdown]
# Inspect stream to see where desired parts are located

# %% [markdown]
# Save Solo Flute part

# %%
flute = s[5]

# %% [markdown]
# # Discreet Sections Pipeline

# %% [markdown]
# Define groups as list where each entry is the measure that a new section starts. Need the last entry to be "end"

# %%
flute_notes =flute.recurse().notes

# %%
grouping = [1, 5, 11, 27, 37, 49, 61, 75, "end"]

# %% [markdown]
# Use the convert_grouping function to convert note list and groups into a list of nodes. Will also return list of section-transition edges

# %%
nodelst_group, transition_edges, pitchdict=mnet.convert_grouping(flute_notes, grouping)
# Out:
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  0
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  1
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  2
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  3
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  4
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  5
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  6
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  7
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8
# In convert, grouping is  [1, 5, 11, 27, 37, 49, 61, 75, 'end']
# g is  8

# %% [markdown]
# Create Graph

# %%
g_group=mnet.create_graph(nodelst_group)
#Write to .gexf
#nx.write_gexf(g_group, "grouped_composition.gexf")

# %% [markdown]
# Generate Random Walk

# %%
randomwalk_group=mnet.generate_randomwalk(g_group)

# %% [markdown]
# Convert random walk to back to music.
#
# Uses conversion function group_strto16thnote, which takes a group pitch string and converts it to a note with length of 16th note. Notes preceeding transition edges will be half notes

# %%
tune = mnet.group_strto16thnote(randomwalk_group)

new_composition_group = mnet.convert_to_stream(tune)

#Write to MIDI
#new_composition_group.write('midi', "new_composition_group.mid")

# %%
g_group.nodes
# Out:
# NodeView(('1_A4', '1_B4', '1_E4', '1_C#5', '1_E5', '1_F#5', '1_D5', '1_G#5', '1_A5', '5_D5', '5_C#5', '5_F#5', '5_A5', '5_B4', '5_E5', '5_D4', '5_A4', '5_D#4', '5_E4', '5_G#4', '5_G#5', '5_B5', '11_A4', '11_D5', '11_C#5', '11_F#5', '11_B4', '11_E5', '11_E4', '11_G#4', '11_A5', '11_F#4', '11_G#5', '11_C#6', '11_B5', '11_A#4', '11_G5', '11_G4', '11_D4', '27_A5', '27_E5', '27_C#5', '27_A4', '27_G5', '27_F#5', '27_D5', '27_B5', '27_D#5', '27_B4', '27_F#4', '27_G#4', '27_E4', '27_D#4', '37_C#5', '37_D5', '37_E5', '37_B4', '37_A4', '37_G#4', '37_E4', '37_F#5', '37_G#5', '37_A5', '37_D#5', '37_F#4', '49_C#5', '49_D5', '49_E5', '49_B4', '49_A4', '49_G#4', '49_E4', '49_F#5', '49_G#5', '49_A5', '49_D#5', '49_F#4', '61_D5', '61_E5', '61_F#5', '61_C#5', '61_B4', '61_A4', '61_A5', '61_G#5', '61_E4', '61_G#4', '75_D5', '75_E5', '75_F#5', '75_C#5', '75_B4', '75_A4', '75_A5', '75_G#5', '75_E4', '75_G#4', 'start', 'end'))

# %% [markdown]
# ## Alter Weight of Transition Nodes

# %% [markdown]
# Test different networkx functions for changing weight

# %%
def degree_reassign(graph, edge, new_degree):
    #improper input
    if new_degree < 0 :
        return None
    
    cur_degree= graph.number_of_edges(edge[0], edge[1])

    difference = new_degree - cur_degree
    
    #Enfoce change - otherwise no effect
    if difference == 0:
        return None
    elif difference > 0:
  
        [graph.add_edge(edge[0], edge[1]) for i in range(difference)]

    elif difference < 0:
        
        difference = difference * -1
        ebunch = [edge]
        [graph.remove_edges_from(ebunch) for i in range(difference)]
    return graph

# %%
degree_reassign(g_group, ('1_A4', '1_B4'), 2)

# %%
g1.edges
# Out:
# OutMultiEdgeView([('1_A4', '1_A4', 0), ('1_A4', '1_B4', 0), ('1_A4', '1_B4', 1), ('1_A4', '1_E4', 0), ('1_A4', '1_E4', 1), ('1_A4', '1_E4', 2), ('1_A4', '1_E4', 3), ('1_A4', '1_E4', 4), ('1_A4', '1_C#5', 0), ('1_A4', '1_C#5', 1), ('1_A4', '1_E5', 0), ('1_A4', '1_E5', 1), ('1_A4', '1_A5', 0), ('1_A4', '1_A5', 1), ('1_A4', '5_D5', 0), ('1_B4', '1_A4', 0), ('1_B4', '1_A4', 1), ('1_B4', '1_C#5', 0), ('1_B4', '1_C#5', 1), ('1_B4', '1_C#5', 2), ('1_E4', '1_A4', 0), ('1_E4', '1_A4', 1), ('1_E4', '1_A4', 2), ('1_E4', '1_A4', 3), ('1_
4', '5_C#5', 0), ('5_A4', '5_E5', 0), ('5_D#4', '5_C#5', 0), ('5_D#4', '5_C#5', 1), ('5_E4', '5_G#4', 0), ('5_E4', '5_G#4', 1), ('5_E4', '5_A4', 0), ('5_E4', '11_A4', 0), ('5_G#4', '5_B4', 0), ('5_G#4', '5_B4', 1), ('5_G#4', '5_E5', 0), ('5_G#4', '5_E5', 1), ('5_G#5', '5_E5', 0), ('5_G#5', '5_E5', 1), ('5_B5', '5_E4', 0), ('11_A4', '11_D5', 0), ('11_A4', '11_D5', 1), ('11_A4', '11_C#5', 0), ('11_A4', '11_C#5', 1), ('11_A4', '11_C#5', 2), ('11_A4', '11_C#5', 3), ('11_A4', '11_E5', 0), ('11_A4', '11_A5', 0), ('11_A4', '11_G#4', 0), ('11_A4', '11_B4', 0), ('11_A4', '11_G4', 0), ('11_A4', '11_D4', 0), ('11_A4', '11_C#6', 0), ('11_A4', '11_G5', 0), ('11_A4', '27_A5', 0), ('11_D5', '11_C#5', 0), ('11_D5', '11_C#5', 1), ('11_D5', '11_C#5', 2), ('11_D5', '11_C#5', 3), ('11_D5', '11_C#5', 4), ('11_D5', '11_C#5', 5), ('11_D5', '11_C#5', 6), ('11_D5', '11_C#5', 7), ('11_D5', '11_C#5', 8), ('11_D5', '11_C#5', 9), ('11_D5', '11_C#5', 10), ('11_D5', '11_B4', 0), ('11_D5', '11_B4', 1), ('11_D5', '11_F#4', 0), ('11_D5', '11_F#4', 1), ('11_D5', '11_E5', 0), ('11_D5', '11_E5', 1), ('11_D5', '11_E5', 2), ('11_D5', '11_F#5', 0), ('11_D5', '11_F#5', 1), ('11_D5', '11_F#5', 2), ('11_D5', '11_D4', 0), ('11_D5', '11_A5', 0), ('11_D5', '11_A4', 0), ('11_D5', '11_A4', 1), ('11_D5', '11_A4', 2), ('11_D5', '11_E4', 0), ('11_D5', '11_B5', 0), ('11_D5', '11_B5', 1), ('11_C#5', '11_F#5', 0), ('11_C#5', '11_B4', 0), ('11_C#5', '11_B4', 1), ('11_C#5', '11_B4', 2), ('11_C#5', '11_B4', 3), ('11_C#5', '11_B4', 4), ('11_C#5', '11_B4', 5), ('11_C#5', '11_B4', 6), ('11_C#5', '11_B4', 7), ('11_ ...

# %%
g_group.edges
# Out:
# OutMultiEdgeView([('1_A4', '1_A4', 0), ('1_A4', '1_B4', 0), ('1_A4', '1_B4', 1), ('1_A4', '1_B4', 2), ('1_A4', '1_E4', 0), ('1_A4', '1_E4', 1), ('1_A4', '1_E4', 2), ('1_A4', '1_E4', 3), ('1_A4', '1_E4', 4), ('1_A4', '1_C#5', 0), ('1_A4', '1_C#5', 1), ('1_A4', '1_E5', 0), ('1_A4', '1_E5', 1), ('1_A4', '1_A5', 0), ('1_A4', '1_A5', 1), ('1_A4', '5_D5', 0), ('1_B4', '1_A4', 0), ('1_B4', '1_A4', 1
('5_A4', '5_F#5', 1), ('5_A4', '5_D4', 0), ('5_A4', '5_D#4', 0), ('5_A4', '5_D#4', 1), ('5_A4', '5_A5', 0), ('5_A4', '5_A5', 1), ('5_A4', '5_E4', 0), ('5_A4', '5_C#5', 0), ('5_A4', '5_E5', 0), ('5_D#4', '5_C#5', 0), ('5_D#4', '5_C#5', 1), ('5_E4', '5_G#4', 0), ('5_E4', '5_G#4', 1), ('5_E4', '5_A4', 0), ('5_E4', '11_A4', 0), ('5_G#4', '5_B4', 0), ('5_G#4', '5_B4', 1), ('5_G#4', '5_E5', 0), ('5_G#4', '5_E5', 1), ('5_G#5', '5_E5', 0), ('5_G#5', '5_E5', 1), ('5_B5', '5_E4', 0), ('11_A4', '11_D5', 0), ('11_A4', '11_D5', 1), ('11_A4', '11_C#5', 0), ('11_A4', '11_C#5', 1), ('11_A4', '11_C#5', 2), ('11_A4', '11_C#5', 3), ('11_A4', '11_E5', 0), ('11_A4', '11_A5', 0), ('11_A4', '11_G#4', 0), ('11_A4', '11_B4', 0), ('11_A4', '11_G4', 0), ('11_A4', '11_D4', 0), ('11_A4', '11_C#6', 0), ('11_A4', '11_G5', 0), ('11_A4', '27_A5', 0), ('11_D5', '11_C#5', 0), ('11_D5', '11_C#5', 1), ('11_D5', '11_C#5', 2), ('11_D5', '11_C#5', 3), ('11_D5', '11_C#5', 4), ('11_D5', '11_C#5', 5), ('11_D5', '11_C#5', 6), ('11_D5', '11_C#5', 7), ('11_D5', '11_C#5', 8), ('11_D5', '11_C#5', 9), ('11_D5', '11_C#5', 10), ('11_D5', '11_B4', 0), ('11_D5', '11_B4', 1), ('11_D5', '11_F#4', 0), ('11_D5', '11_F#4', 1), ('11_D5', '11_E5', 0), ('11_D5', '11_E5', 1), ('11_D5', '11_E5', 2), ('11_D5', '11_F#5', 0), ('11_D5', '11_F#5', 1), ('11_D5', '11_F#5', 2), ('11_D5', '11_D4', 0), ('11_D5', '11_A5', 0), ('11_D5', '11_A4', 0), ('11_D5', '11_A4', 1), ('11_D5', '11_A4', 2), ('11_D5', '11_E4', 0), ('11_D5', '11_B5', 0), ('11_D5', '11_B5', 1), ('11_C#5', '11_F#5', 0), ('11_C#5', '11_B4', 0), ('11_C#5', '11_B4', 1), ('11_C#5', '11_B4', 2), ('11_C#5', '11_B4', 3), ('11_C#5', '11_B4', 4), ('11_C#5', '11_B4', 5), ('11_C#5', '11_B4', 6), ('11_C#5 ...

# %%
ebunch = [('1_A4', '1_B4')]
g_group.remove_edges_from(ebunch)

# %%
g_group.edges
# Out:
), ('5_E5', '5_B4', 0), ('5_E5', '5_B4', 1), ('5_E5', '5_E4', 0), ('5_E5', '5_E4', 1), ('5_E5', '5_B5', 0), ('5_D4', '5_C#5', 0), ('5_D4', '5_C#5', 1), ('5_A4', '5_F#5', 0), ('5_A4', '5_F#5', 1), ('5_A4', '5_D4', 0), ('5_A4', '5_D#4', 0), ('5_A4', '5_D#4', 1), ('5_A4', '5_A5', 0), ('5_A4', '5_A5', 1), ('5_A4', '5_E4', 0), ('5_A4', '5_C#5', 0), ('5_A4', '5_E5', 0), ('5_D#4', '5_C#5', 0), ('5_D#4', '5_C#5', 1), ('5_E4', '5_G#4', 0), ('5_E4', '5_G#4', 1), ('5_E4', '5_A4', 0), ('5_E4', '11_A4', 0), ('5_G#4', '5_B4', 0), ('5_G#4', '5_B4', 1), ('5_G#4', '5_E5', 0), ('5_G#4', '5_E5', 1), ('5_G#5', '5_E5', 0), ('5_G#5', '5_E5', 1), ('5_B5', '5_E4', 0), ('11_A4', '11_D5', 0), ('11_A4', '11_D5', 1), ('11_A4', '11_C#5', 0), ('11_A4', '11_C#5', 1), ('11_A4', '11_C#5', 2), ('11_A4', '11_C#5', 3), ('11_A4', '11_E5', 0), ('11_A4', '11_A5', 0), ('11_A4', '11_G#4', 0), ('11_A4', '11_B4', 0), ('11_A4', '11_G4', 0), ('11_A4', '11_D4', 0), ('11_A4', '11_C#6', 0), ('11_A4', '11_G5', 0), ('11_A4', '27_A5', 0), ('11_D5', '11_C#5', 0), ('11_D5', '11_C#5', 1), ('11_D5', '11_C#5', 2), ('11_D5', '11_C#5', 3), ('11_D5', '11_C#5', 4), ('11_D5', '11_C#5', 5), ('11_D5', '11_C#5', 6), ('11_D5', '11_C#5', 7), ('11_D5', '11_C#5', 8), ('11_D5', '11_C#5', 9), ('11_D5', '11_C#5', 10), ('11_D5', '11_B4', 0), ('11_D5', '11_B4', 1), ('11_D5', '11_F#4', 0), ('11_D5', '11_F#4', 1), ('11_D5', '11_E5', 0), ('11_D5', '11_E5', 1), ('11_D5', '11_E5', 2), ('11_D5', '11_F#5', 0), ('11_D5', '11_F#5', 1), ('11_D5', '11_F#5', 2), ('11_D5', '11_D4', 0), ('11_D5', '11_A5', 0), ('11_D5', '11_A4', 0), ('11_D5', '11_A4', 1), ('11_D5', '11_A4', 2), ('11_D5', '11_E4', 0), ('11_D5', '11_B5', 0), ('11_D5', '11_B5', 1), ('11_C#5', '11_F#5', 0), ('11_C#5', '11_B4', 0), ('11_C#5', '11_B4', 1), ('11_C#5', '11_B4', 2), ('11_C#5', '11_B4', 3), ('11_C#5', '11_B4', 4), ('11_C#5', '11_B4', 5), ('11_C#5', '11_B4', 6), ('11_C#5', '11_B4', 7), ('11_ ...

# %% [markdown]
# Currently all transition edges have a weight of 1. This can be altered through degree_increase()

# %%
transition_edges
# Out:
# [('1 A4', '5 D5'),
#  ('5 E4', '11 A4'),
#  ('11 A4', '27 A5'),
#  ('27 E4', '37 C#5'),
#  ('37 E4', '49 C#5'),
#  ('49 E4', '61 D5'),
#  ('61 A4', '75 D5')]

# %%
graph_adjusted1 = mnet.degree_increase(g_group, [transition_edges[2]], increase=10)

# %% [markdown]
# The weight of the outgoing edge affects how much time the random walker will stay in a givin section. By changing this weight, you have some degree of control over how long a section will go for.

# %% [markdown]
# Page Rank

# %%
g_weighted = mnet.convert_to_weighted(g_group)

# %% [markdown]
# Convert to json

# %%
from networkx.readwrite import json_graph

data = json_graph.node_link_data( mnet.convert_to_weighted(g_weighted))

# %%
import json
with open('grouped.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
ranking = nx.pagerank(g_weighted)

# %%
len(ranking)

# %% [markdown]
# Module Leaving Probability
#
#     ni : number of nodes in module i
#
#     alpha : node label
#
#     tau: probability of teleportation  --> very small could make constant
#
#     p_alpha: probability of being at node (pagerank)
#
#     w_alpha_beta : weight of link from node alpha to node beta

# %%
def exit_probability(steps, graph, module, ranking, tau=.15):
    n = len(graph.nodes)
    ni = len(module.nodes)
    
    #teleportation term - may remove
    sum_rank=0
    for alpha in module.nodes:
        sum_rank += ranking[alpha]
        
    #exit term
    sum_exit_rank_weight = 0
    for edge in graph.edges():
        if edge[0] in module.nodes and edge[1] not in module.nodes:
            weight=graph.get_edge_data(edge[0], edge[1])['weight']
            print(weight)
            print(ranking[edge[0]])
            print(edge[0])
            print(edge[1])
            sum_exit_rank_weight += ranking[edge[0]] * weight
    
    step_exit_probability = tau * ((n-ni)/(n-1)) * sum_rank + (1-tau) * sum_exit_rank_weight
    print('step exit probability', step_exit_probability)
    exit_probability = step_exit_probability * ((1-step_exit_probability) ** (steps-1))
    
    return exit_probability

# %%
g_group = mnet.degree_increase(g_weighted, [('1 A4', '5 D5')], 30)

# %% [markdown]
# Isolate Module

# %%
module = g_weighted.subgraph(['1 A4', \
        '1 B4', '1 E4', '1 C#5', '1 E5', '1 A5', \
                              '1 D5', '1 F#5', '1 G#5'])

# %% [markdown]
# Calc pagerank -liklihood a random walker will be at a particular node

# %%
ranking = nx.pagerank(g_weighted)

# %%
ranking['5 D5']

# %%
exit_1=exit_probability(1, g_weighted, module, ranking, tau=.5)
exit_1

# %%
exit_2=exit_probability(2, g_weighted, module, ranking, tau=.5)
exit_2

# %%
exit_3=exit_probability(20, g_weighted, module, ranking, tau=.01)
exit_3

# %% [markdown]
# ### Ground Truth for length probabilities

# %% [markdown]
# Isolate subgraph

# %%
subgraph = g_group.subgraph(['1 A4', \
        '1 B4', '1 E4', '1 C#5', '1 E5', '1 A5', \
                              '1 D5', '1 F#5', '1 G#5', '5 D5'])

# %%
arr = mnet.gen_path_histogram(subgraph,  '1 A4',  ('1 A4', '5 D5'), outgoing_edge_weight=10, additional_depth=3)

# %%
arr
